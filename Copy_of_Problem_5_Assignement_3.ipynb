# %% [markdown]
# #  Problem 5

# %% [markdown]
# 1. Your Name:Walelign Sumoro
# 2. Section: CISC 121
# 3. ID: 20476619
# 4. Github Link of this notebook:
# 5. Chat link with AI tool:

# %% [markdown]
# ## 1. Understanding & Breakdown
# 1) Understanding & Breakdown
#
# Input: two strings s, t.
#
# Output: True/False if t is an anagram of s.
#
# Plan: If lengths differ → false. Otherwise compare char counts. Sorting also works but is O(n log n); counting is O(n).

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# What I learned: A fixed‑size count (26 letters) or hashmap works; beware Unicode/generalization.
# Here is what i have reviewed: https://leetcode.com/problems/valid-anagram/solutions/7324864/valid-anagram-simple-solution-by-dk97_97-2n2h/

# %% [markdown]
# Here is the draft code

# %%
def isAnagram(s: str, t: str) -> bool:
if len(s) != len(t):
return False
return sorted(s) == sorted(t)

# %% [markdown]
# ## 3. Final Correct Code

# %%
from collections import Counter


def isAnagram(s: str, t: str) -> bool:
if len(s) != len(t):
return False
return Counter(s) == Counter(t)

# %% [markdown]
# ## 4. Review & Fixes

# %% [markdown]
# Fix 1: Replaced O(n log n) sort with O(n) Counter comparison.
#
# Fix 2: Added early length check to avoid unnecessary work.

# %% [markdown]
# ## 5. Reflection on Your Contribution
# I added tests with repeated characters and with different lengths to ensure the early exit works.
