# %% [markdown]
# #  Problem 4

# %% [markdown]
# 1. Your Name:Walelign Sumoro
# 2. Section: CISC 121
# 3. ID: 20476619
# 4. Github Link of this notebook:
# 5. Chat link with AI tool:

# %% [markdown]
# ## 1. Understanding & Breakdown
# 1) Understanding & Breakdown
#
# Input: versions 1..n, boolean API isBadVersion(v).
#
# Output: smallest v that is bad.
#
# Plan: Binary search on predicate: move right = mid when bad; else left = mid+1.

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# What I learned: Prefer while left < right and shrink toward the first bad.
# Here is what i have reviewed: https://leetcode.com/problems/first-bad-version/solutions/7291645/python-optimal-solution-by-behrooz_q-z3be/

# %% [markdown]
# Here is the draft code

# %%
def firstBadVersion(n: int) -> int:
l, r = 1, n
ans = n
while l <= r:
m = (l + r) // 2
if isBadVersion(m):
ans = m
r = m - 1
else:
l = m + 1
return ans

# %% [markdown]
# ## 3. Final Correct Code

# %%
def firstBadVersion(n: int) -> int:
left, right = 1, n
while left < right:
mid = (left + right) // 2
if isBadVersion(mid):
right = mid
else:
left = mid + 1
return left

# %% [markdown]
# ## 4. Review & Fixes

# %% [markdown]
# Fix 1: Switched to left<right shrinking window to avoid off‑by‑one bugs.
#
# Fix 2: Removed unnecessary ans variable.

# %% [markdown]
# ## 5. Reflection on Your Contribution
# I checked boundaries when the first bad is 1 and when it’s n to ensure correctness.
