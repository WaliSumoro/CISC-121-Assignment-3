# %% [markdown]
# #  Problem 2

# %% [markdown]
# 1. Your Name:Walelign Sumoro
# 2. Section: CISC 121
# 3. ID: 20476619
# 4. Github Link of this notebook:https://github.com/WaliSumoro/CISC-121-Assignment-3/blob/main/Problem_1_Assignement_3.ipynb
# 5. Chat link with AI tool:

# %% [markdown]
# ## 1. Understanding & Breakdown
# 1) Understanding & Breakdown
#
# Input: students prefs (0=round, 1=square), sandwiches stack top‑first.
#
# Output: count of students who can’t eat.
#
# Constraints: Swap students to end if they don’t want top sandwich; stop when a full cycle makes no progress.
#
# Plan: Observation: only counts of 0/1 matter. Iterate sandwiches; if count[type]==0 break; else decrement.

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# What I learned: The queue simulation can be reduced to frequency matching → O(n).
# Here is what i have reviewed: https://leetcode.com/problems/number-of-students-unable-to-eat-lunch/solutions/7348672/simple-python-queue-beats-100-by-milburn-wzu0/?envType=problem-list-v2&envId=queue

# %% [markdown]
# Here is the draft code

# %%
from collections import Counter


def countStudents(students, sandwiches):
freq = Counter(students)
for s in sandwiches:
if freq[s] == 0:
return freq[0] + freq[1]
freq[s] -= 1
return 0

# %% [markdown]
# ## 3. Final Correct Code

# %%
from collections import Counter


def countStudents(students, sandwiches):
freq = Counter(students)
for s in sandwiches:
if freq[s] == 0:
return freq[0] + freq[1]
freq[s] -= 1
return 0

# %% [markdown]
# ## 4. Review & Fixes

# %% [markdown]
# Fix 1: Dropped full queue simulation → replaced with simple counts.
#
# Fix 2: Explicit return of the remaining sum at break.

# %% [markdown]
# ## 5. Reflection on Your Contribution
# I validated with cases where all want 1 but top sandwich is 0 (should exit immediately with all students remaining).
