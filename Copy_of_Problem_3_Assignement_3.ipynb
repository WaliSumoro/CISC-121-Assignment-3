# %% [markdown]
# #  Problem 3

# %% [markdown]
# 1. Your Name:Walelign Sumoro
# 2. Section: CISC 121
# 3. ID: 20476619
# 4. Github Link of this notebook:
# 5. Chat link with AI tool:

# %% [markdown]
# ## 1. Understanding & Breakdown
# 1) Understanding & Breakdown
#
# Input: n steps; climb 1 or 2 each time.
#
# Output: number of distinct ways.
#
# Plan: Fibonacci: f(n)=f(n-1)+f(n-2) with base f(1)=1, f(2)=2. Use iterative DP to avoid recursion blow‑up.

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# What I learned: Top‑down recursion is exponential unless memoized; iterative DP is O(n) time, O(1) space.
# Here is what i have reviewed: https://leetcode.com/problems/climbing-stairs/solutions/1531764/python-detail-explanation-3-solutions-ea-p8g7/

# %% [markdown]
# Here is the draft code

# %%
def climbStairs(n: int) -> int:
if n <= 2:
return n
return climbStairs(n-1) + climbStairs(n-2)

# %% [markdown]
# ## 3. Final Correct Code

# %%
def climbStairs(n: int) -> int:
if n <= 2:
return n
a, b = 1, 2
for _ in range(3, n + 1):
a, b = b, a + b
return b

# %% [markdown]
# ## 4. Review & Fixes

# %% [markdown]
# Fix 1: Replaced exponential recursion with iterative DP.
#
# Fix 2: Added early return for n ≤ 2.

# %% [markdown]
# ## 5. Reflection on Your Contribution
# I traced n=3..6 by hand to confirm the sequence 1,2,3,5,8,13.
